# %% [markdown]
# # **ASSIGNMENT 5 – Real-World Function-Based Problem Solving**

# %%
# Problem 1: Social Media – Post Engagement Analyzer

def analyze_post_engagement(likes_list):
    total_likes = sum(likes_list)

    print(f"Total Likes: {total_likes}")

    if total_likes >= 1000:
        print("Post Status: Viral Post")
    else:
        print("Post Status: Normal Engagement")

# Example usage to match the expected output format
example_likes = [500, 300, 250] # Sums to 1050
analyze_post_engagement(example_likes)
# Out:
# Total Likes: 1050
# Post Status: Viral Post

# %%
# Problem 2: Healthcare – Medicine Stock Alert System

def medicine_stock_alert(stock):
    if stock < 10:
        return "Low Stock Alert"
    else:
        return "Stock Sufficient"

# Example usage:
stock_level = 6
status = medicine_stock_alert(stock_level)
print(f"Medicine Stock: {stock_level}")
print(f"Status: {status}")
# Out:
# Medicine Stock: 6
# Status: Low Stock Alert

# %%
# Problem 3: Agriculture – Rainfall Adequacy Checker

def rainfall_adequacy_checker(rainfall_data):
    if not rainfall_data:
        return 0, "No data available"

    average_rainfall = sum(rainfall_data) / len(rainfall_data)
    required_level = 50

    status = ""
    if average_rainfall >= required_level:
        status = "Adequate Rainfall"
    else:
        status = "Inadequate Rainfall"

    return average_rainfall, status

# Example usage:
example_rainfall = [60, 70, 80, 65, 75]

example_rainfall_for_output = [70, 75, 80, 68, 67]

average, status = rainfall_adequacy_checker(example_rainfall_for_output)

print(f"Average Rainfall: {average:.0f}")
print(f"Rainfall Status: {status}")
# Out:
# Average Rainfall: 72
# Rainfall Status: Adequate Rainfall

# %%
# Problem 4: Social Media – Duplicate Account Detection

def detect_duplicate_accounts(usernames):
    unique_users = set(usernames)

    if len(unique_users) != len(usernames):
        return "Duplicate Accounts Found: Yes"
    else:
        return "Duplicate Accounts Found: No"


# Predefined usernames list
usernames = ["john", "emma", "alex", "john", "mike"]

result = detect_duplicate_accounts(usernames)
print(result)
# Out:
# Duplicate Accounts Found: Yes

# %%
# Problem 5: Healthcare – Appointment Eligibility Checker

def health_care_appointment_checker(age):
  if age >= 18:
    return "Eligible"
  elif age < 18:
    return "Not Eligible"



age = 21
print(f"Patient Age: {age}")
print(f"Eligibility Status: {health_care_appointment_checker(age)}")
# Out:
# Patient Age: 21
# Eligibility Status: Eligible

# %%
# Problem 6: Agriculture – Premium Crop Price Filter

def premium_crop_filter(prices):
  premium_crops = []
  for price in prices:
    if price > 2000:
      premium_crops.append(price)
  return premium_crops


prices = [1000, 2500, 3200, 2000, 650]

print(f"Premium Crops: {premium_crop_filter(prices)}")
# Out:
# Premium Crops: [2500, 3200]

# %%
# Problem 7: System Monitoring – Application Health Checker

def application_health_checker(errors):
    if errors == 0:
        return "Healthy"
    elif 0 < errors <= 5:
        return "Minor Issues"
    else:
        return "Critical Issues"

# Example usage:
error_count = 7
status = application_health_checker(error_count)
print(f"Error Count: {error_count}")
print(f"System Status: {status}")
# Out:
# Error Count: 7
# System Status: Critical Issues

# %%
# Problem 8: Banking – Daily Transaction Limit Checker

def daily_transaction_limit_checker(amount):
    daily_limit = 50000
    if amount <= daily_limit:
        return "Approved"
    else:
        return "Rejected"

# Example usage:
transaction_amount = 60000
status = daily_transaction_limit_checker(transaction_amount)
print(f"Transaction Amount: {transaction_amount}")
print(f"Transaction Status: {status}")
# Out:
# Transaction Amount: 60000
# Transaction Status: Rejected

# %%
# Problem 9: E-Learning – Student Attendance Eligibility System

def check_attendance_eligibility(attendance_records):
    total_days = len(attendance_records)
    if total_days == 0:
        return 0.0, "Not Applicable"

    present_days = sum(attendance_records)
    attendance_percentage = (present_days / total_days) * 100

    if attendance_percentage >= 75:
        eligibility_status = "Eligible"
    else:
        eligibility_status = "Not Eligible"

    return attendance_percentage, eligibility_status

# Example usage:
student_attendance = [1, 1, 1, 0, 1, 1, 1, 1, 0, 1]

percentage, eligibility = check_attendance_eligibility(student_attendance)

print(f"Attendance Percentage: {percentage:.1f}")
print(f"Exam Eligibility: {eligibility}")
# Out:
# Attendance Percentage: 80.0
# Exam Eligibility: Eligible

# %%
# Problem 10: Smart Electricity Bill Analyzer

def calculate_electricity_bill_and_usage(units):
    total_bill = 0

    # Calculate bill based on units consumed
    if units <= 100:
        total_bill = units * 3
    elif units <= 200:
        total_bill = (100 * 3) + ((units - 100) * 5)
    else:
        total_bill = (100 * 3) + (100 * 5) + ((units - 200) * 7)

    # Classify usage level
    usage_status = ""
    if total_bill < 500:
        usage_status = "Low Usage"
    elif 500 <= total_bill <= 1500:
        usage_status = "Moderate Usage"
    else:
        usage_status = "High Usage"

    return total_bill, usage_status

# Example usage:
units_consumed = 250
bill, usage = calculate_electricity_bill_and_usage(units_consumed)

print(f"Units Consumed: {units_consumed}")
print(f"Total Bill: ₹{bill}")
print(f"Usage Status: {usage}")
# Out:
# Units Consumed: 250
# Total Bill: ₹1150
# Usage Status: Moderate Usage
